# %% [markdown]
# # Individual Agent Demonstrations
#
# This notebook demonstrates how each specialized agent works independently.

# %%
# Databricks notebook source
# MAGIC %md
# MAGIC ## Setup
# MAGIC 
# MAGIC Import agents and configure environment.

import sys
sys.path.append('/Workspace/Repos/your-repo/stocks')

from datetime import date, timedelta
from src.agents.fundamentals_agent import FundamentalsAgent
from src.agents.valuation_agent import ValuationAgent
from src.agents.macro_agent import MacroAgent
from src.agents.events_agent import EventsAgent
from src.agents.technical_agent import TechnicalAgent
from src.agents.sector_agent import SectorAgent

# %%
# MAGIC %md
# MAGIC ## Fundamentals Agent
# MAGIC 
# MAGIC Analyzes company financial metrics and fundamentals.

fundamentals_agent = FundamentalsAgent()
symbol = "AAPL"
prediction = fundamentals_agent.generate_prediction(symbol)

print(f"Predicted Return: {prediction.predicted_return:+.2f}%")
print(f"Confidence: {prediction.confidence_score:.2f}")
print(f"\nReasoning:\n{prediction.reasoning}")
print(f"\nKey Factors: {', '.join(prediction.key_factors)}")
